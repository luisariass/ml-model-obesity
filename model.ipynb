# %%
import pandas as pd
from IPython.display import display

# %%
df = pd.read_excel("C:/Users/luisarias/Documents/ml-model-obesity/data/ObesityDataSet.xlsx")
df.head()
# Split the single column into multiple columns based on the delimiter ','
df = df[df.columns[0]].str.split(',', expand=True)

# Assign proper column names
df.columns = col.split(',')

# Display the first 5 rows of the organized dataframe
display(df.head(30))
# Out:
#     Gender Age Height Weight family_history_with_overweight FAVC FCVC NCP  \
# 0   Female  21   1.62     64                            yes   no    2   3
# 1   Female  21   1.52     56                            yes   no    3   3
# 2     Male  23    1.8     77                            yes   no    2   3
# 3     Male  27    1.8     87                             no   no    3   3
# 4     Male  22   1.78   89.8                             no   no    2   1
# 5     Male  29   1.62     53                             no  yes    2   3
# 6   Female  23    1.5     55                            yes  yes    3   3
# 7     Male  22   1.64     53                             no   no    2   3
# 8     Male  24   1.78     64                            yes  yes    3   3
# 9     Male  22   1.72     68                            yes  yes    2   3
# 10    Male  26   1.85    105                            yes  yes    3   3
# 11  Female  21   1.72     80                            yes  yes    2   3
# ...

# %%
df.columns
for col in df.columns:
    print(col)
# Out:
# Gender,Age,Height,Weight,family_history_with_overweight,FAVC,FCVC,NCP,CAEC,SMOKE,CH2O,SCC,FAF,TUE,CALC,MTRANS,NObeyesdad
