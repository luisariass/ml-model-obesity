# %%
import pandas as pd
from IPython.display import display

# %%
# ...existing code...
df = pd.read_excel("C:/Users/luisarias/Documents/ml-model-obesity/data/ObesityDataSet.xlsx")
# Assuming the first column contains the comma-separated data
# And assuming the first row might be headers you want to skip in the data part
df_data = pd.read_excel("C:/Users/luisarias/Documents/ml-model-obesity/data/ObesityDataSet.xlsx", header=None, skiprows=1) # Adjust skiprows if needed
df = df_data[df_data.columns[0]].str.split(',', expand=True)


# Define the 17 column names manually
correct_column_names = [
    'Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
    'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
    'CALC', 'MTRANS', 'NObesity' # Make sure you have exactly 17 names here
]

# Assign proper column names
if len(correct_column_names) == len(df.columns):
    df.columns = correct_column_names
else:
    print(f"Error: Number of columns after split ({len(df.columns)}) does not match number of defined headers ({len(correct_column_names)}).")


# Display the first few rows of the organized dataframe
display(df.head(10))
# ...existing code...
# Out:
#    Gender Age Height Weight family_history_with_overweight FAVC FCVC NCP  \
# 0  Female  21   1.62     64                            yes   no    2   3
# 1  Female  21   1.52     56                            yes   no    3   3
# 2    Male  23    1.8     77                            yes   no    2   3
# 3    Male  27    1.8     87                             no   no    3   3
# 4    Male  22   1.78   89.8                             no   no    2   1
# 5    Male  29   1.62     53                             no  yes    2   3
# 6  Female  23    1.5     55                            yes  yes    3   3
# 7    Male  22   1.64     53                             no   no    2   3
# 8    Male  24   1.78     64                            yes  yes    3   3
# 9    Male  22   1.72     68                            yes  yes    2   3
#
#         CAEC SMOKE CH2O  SCC FAF TUE        CALC                 MTRANS  \
# 0  Sometimes    no    2   no   0   1          no  Public_Transportation
# ...

# %%
df.columns
for col in df.columns:
    print(col)
# Out:
# Gender,Age,Height,Weight,family_history_with_overweight,FAVC,FCVC,NCP,CAEC,SMOKE,CH2O,SCC,FAF,TUE,CALC,MTRANS,NObeyesdad
